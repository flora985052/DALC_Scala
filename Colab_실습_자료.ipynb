# %% [markdown]
# # Colab 실습 하기

# %% [markdown]
# ## 1. 마크다운으로 내 깃허브 링크 삽입하기

# %% [markdown]
# [이민주 깃허브](https://github.com/flora985052)

# %% [markdown]
# ## 2. 마크다운으로 이미지 삽입하기

# %% [markdown]
# ![icebear](https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory&fname=http%3A%2F%2Fcfile23.uf.tistory.com%2Fimage%2F9994FC475CDE72061CF842)

# %% [markdown]
# ## 3. 마크다운으로 수업 배운 것 정리해보기

# %% [markdown]
# - **전략적브랜드관리** <br/>
# → IT 산업 각광 전 코라콜라가 글로벌 브랜드 1위 였는데 지금은 5위 밖으로 떨어졌다  <br/>
# → 2020년 기준 **1위 애플 / 2위 아마존 / 3위 마이크로소프트** 이며 1위부터 5위까지가 IT 회사이다 <br/>
# <br/>
# - **컴활 실기** <br/>
# → 유동균 성대모사 <br/>
# <br/>
# - **DALC** <br/>
# → 깃허브를 제대로 처음 써봤다. 이미지 넣기에서 링크때문에 애먹었는데 알려주셔서 잘 해결할 수 있었다
